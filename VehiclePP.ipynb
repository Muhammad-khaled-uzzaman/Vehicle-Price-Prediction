# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd

# %%
car = pd.read_csv('/content/gdrive/MyDrive/train-data.csv')
backup = car.copy()

# %% [markdown]
# ## what preprocessing required
# - change milage(kmpl), engine(CC), power(bph) to only number
# - remove new_price
# - add company name column
# - change name to 3 digits
# - remove null

# %%
car_new = ['Name',	'Location',	'Year',	'Kilometers_Driven',	'Fuel_Type',	'Transmission',	'Owner_Type',	'Mileage',	'Engine'	,	'Seats', 'Price']
car = car[car_new]

# %%
car['company'] = car['Name'].str.split(' ').str.get(0).str.replace(',','')
car['Name'] = car['Name'].str.split(' ').str.slice(0,3).str.join(' ')
car['Mileage'] = car['Mileage'].str.split(' ').str.get(0)
car['Engine'] = car['Engine'].str.split(' ').str.get(0)

# %%
#removing 'Fourth & Above' from Owner_Type as 9 data only there
car = car[car['Owner_Type'] != 'Fourth & Above'].reset_index(drop=True)
#remove car with seats = 0 as it missleads the other data
car = car[car['Seats'] != 0.0].reset_index(drop=True)
# there is only one data with more then 6^6 km so delete it
car = car[car['Kilometers_Driven'] < 6e6].reset_index(drop=True)

# %%
#removed all row with null data(it was very few)
car = car.dropna()

# %%
car['Mileage'] = car['Mileage'].astype(float)
car['Engine'] = car['Engine'].astype(int)
car['Seats'] = car['Seats'].astype(int)

# %%
car = car.reset_index(drop=True)
car
# Out:
#                        Name    Location  Year  Kilometers_Driven Fuel_Type  \
# 0            Maruti Wagon R      Mumbai  2010              72000       CNG
# 1         Hyundai Creta 1.6        Pune  2015              41000    Diesel
# 2              Honda Jazz V     Chennai  2011              46000    Petrol
# 3         Maruti Ertiga VDI     Chennai  2012              87000    Diesel
# 4               Audi A4 New  Coimbatore  2013              40670    Diesel
# ...                     ...         ...   ...                ...       ...
# 5960       Maruti Swift VDI       Delhi  2014              27365    Diesel
# 5961      Hyundai Xcent 1.1      Jaipur  2015             100000    Diesel
# 5962       Mahindra Xylo D4      Jaipur  2012              55000    Diesel
# 5963         Maruti Wagon R     Kolkata  2013              46000    Petrol
# 5964  Chevrolet Beat Diesel   Hyderabad  2011              47000    Diesel
#
#      Transmission Owner_Type  Mileage  Engine  Seats  Price    company
# 0          Manual      First    26.60     998      5   1.75     Maruti
# 1          Manual      First    19.67    1582      5  12.50    Hyundai
# 2          Manual      First    18.20    1199      5   4.50      Honda
# 3          Manual      First    20.77    1248      7   6.00     Maruti
# 4       Automatic     Second    15.20    1968      5  17.74       Audi
# ...           ...        ...      ...     ...    ...    ...        ...
# 5960       Manual      First    28.40    1248      5   4.75     Maruti
# 5961       Manual      First    24.40    1120      5   4.00    Hyundai
# 5962       Manual     Second    14.00    2498      8   2.90   Mahindra
# 5963       Manual      First    18.90     998      5   2.65     Maruti
# 5964       Manual      First    25.44     936      5   2.50  Chevrolet
#
# [5965 rows x 12 columns]

# %%
car.shape
# Out:
# (5965, 12)

# %%
car.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5965 entries, 0 to 5964
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Name               5965 non-null   object
#  1   Location           5965 non-null   object
#  2   Year               5965 non-null   int64
#  3   Kilometers_Driven  5965 non-null   int64
#  4   Fuel_Type          5965 non-null   object
#  5   Transmission       5965 non-null   object
#  6   Owner_Type         5965 non-null   object
#  7   Mileage            5965 non-null   float64
#  8   Engine             5965 non-null   int64
#  9   Seats              5965 non-null   int64
#  10  Price              5965 non-null   float64
#  11  company            5965 non-null   object
# dtypes: float64(2), int64(4), object(6)
# memory usage: 559.3+ KB

# %%
car.describe()
# Out:
#               Year  Kilometers_Driven      Mileage       Engine        Seats  \
# count  5965.000000        5965.000000  5965.000000  5965.000000  5965.000000
# mean   2013.395138       57478.155742    18.189554  1620.660184     5.278458
# std       3.239378       37689.537531     4.514490   600.438234     0.804548
# min    1998.000000         171.000000     0.000000   624.000000     2.000000
# 25%    2012.000000       33858.000000    15.260000  1198.000000     5.000000
# 50%    2014.000000       53000.000000    18.190000  1493.000000     5.000000
# 75%    2016.000000       72921.000000    21.100000  1984.000000     5.000000
# max    2019.000000      775000.000000    33.540000  5998.000000    10.000000
#
#              Price
# count  5965.000000
# mean      9.499106
# std      11.189206
# min       0.440000
# 25%       3.500000
# 50%       5.650000
# 75%       9.950000
# max     160.000000

# %%
car.to_csv('/content/gdrive/MyDrive/Cleaned Car.csv')

# %% [markdown]
# **cleaning done!**

# %% [markdown]
# ## Model
# - Linear Regression
# - random forest
# - Navie bays

# %%
x = car.drop(columns='Price')
y = car['Price']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(x,y, test_size = 0.2)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import r2_score
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import make_column_transformer
from sklearn.pipeline import make_pipeline

# %%
ohe = OneHotEncoder()
ohe.fit(x[['Name','Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'company']])
# Out:
# OneHotEncoder()

# %%
column_trans = make_column_transformer((OneHotEncoder(categories=ohe.categories_),['Name','Location', 'Fuel_Type', 'Transmission', 'Owner_Type', 'company']),remainder="passthrough")

# %% [markdown]
# **Linear Regression**

# %%
lr = LinearRegression()
pipe = make_pipeline(column_trans,lr)
pipe.fit(X_train,Y_train)
y_pred = pipe.predict(X_test)
r2_score(Y_test,y_pred)
# Out:
# 0.7737943226159467

# %%
pipe.predict(pd.DataFrame([['Hyundai i20 Sportz','Ahmedabad',2015,110000,'Diesel','Manual','First', 20.00, 	1400,	5,'Hyundai']],columns=['Name',	'Location',	'Year',	'Kilometers_Driven',	'Fuel_Type',	'Transmission',	'Owner_Type',	'Mileage',	'Engine',	'Seats',	'company']))
# Out:
# array([7.65630644])

# %%
#for slection of car object
pipe.steps[0][1].transformers[0][1].categories[1]
# Out:
# array(['Ahmedabad', 'Bangalore', 'Chennai', 'Coimbatore', 'Delhi',
#        'Hyderabad', 'Jaipur', 'Kochi', 'Kolkata', 'Mumbai', 'Pune'],
#       dtype=object)

# %% [markdown]
# **Random Forest**

# %%
reg = RandomForestRegressor()
pipe_reg = make_pipeline(column_trans,reg)
pipe_reg.fit(X_train,Y_train)
y_pred_reg = pipe_reg.predict(X_test)
r2_score(Y_test,y_pred_reg)
# Out:
# 0.8850907015258599

# %%
pipe.predict(pd.DataFrame([['Hyundai i20 Sportz','Ahmedabad',2015,110000,'Diesel','Manual','First', 20.00, 	1400,	5,'Hyundai']],columns=['Name',	'Location',	'Year',	'Kilometers_Driven',	'Fuel_Type',	'Transmission',	'Owner_Type',	'Mileage',	'Engine',	'Seats',	'company']))
# Out:
# array([7.65630644])

# %%
#for slection of car object
pipe.steps[0][1].transformers[0][1].categories[0]
# Out:
# array(['Ambassador Classic Nova', 'Audi A3 35', 'Audi A4 1.8',
#        'Audi A4 2.0', 'Audi A4 3.0', 'Audi A4 30', 'Audi A4 35',
#        'Audi A4 New', 'Audi A6 2.0', 'Audi A6 2.7', 'Audi A6 2.8',
#        'Audi A6 2011-2015', 'Audi A6 3.0', 'Audi A6 35',
#        'Audi A7 2011-2015', 'Audi A8 L', 'Audi Q3 2.0',
#        'Audi Q3 2012-2015', 'Audi Q3 30', 'Audi Q3 35', 'Audi Q5 2.0',
#        'Audi Q5 2008-2012', 'Audi Q5 3.0', 'Audi Q5 30', 'Audi Q7 3.0',
#        'Audi Q7 35', 'Audi Q7 4.2', 'Audi Q7 45', 'Audi RS5 Coupe',
#        'Audi TT 2.0', 'Audi TT 40', 'BMW 1 Series', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 6 Series', 'BMW 7 Series', 'BMW X1 M',
#        'BMW X1 sDrive', 'BMW X1 sDrive20d', 'BMW X1 xDrive',
#        'BMW X3 xDrive', 'BMW X3 xDrive20d', 'BMW X3 xDrive30d',
#        'BMW X5 2014-2019', 'BMW X5 3.0d', 'BMW X5 X5', 'BMW X5 xDrive',
#        'BMW X6 xDrive', 'BMW X6 xDrive30d', 'BMW Z4 2009-2013',
#        'Bentley Continental Flying', 'Chevrolet Aveo 1.4',
#        'Chevrolet Aveo 1.6', 'Chevrolet Aveo U-VA',
#        'Chevrolet Beat Diesel', 'Chevrolet Beat LS', 'Chevrolet Beat LT',
#        'Chevrolet Beat Option', 'Chevrolet Captiva LT',
#        'Chevrolet Captiva LTZ', 'Chevrolet Cruze LTZ',
#        'Chevrolet Enjoy 1.3', 'Chevrolet Enjoy 1.4',
#        'Chevrolet Enjoy Petrol', 'Chevrolet Enjoy TCDi',
#        'Chevrolet Optra 1.6', 'Chevrolet Optra Magnum',
#        'Chevrolet Sail 1.2', 'Chevrolet Sail Hatchback',
#        'Chevrolet Sail LT', 'Chevrolet Spark 1.0', 'Chevrolet Tavera LS',
#        'Chevrolet Tavera LT', 'Datsun GO NXT', 'Datsun GO Plus',
#        'Datsun GO T', 'Datsun Redi GO', 'Datsun redi-GO S',
#        'Datsun redi-GO T', 'Fiat Avventura MULTIJET', 'Fiat Grande Punto',
#        'Fiat Linea 1.3', 'Fiat Linea Classic', 'Fiat Linea Emotion',
#        'Fiat Linea T', 'Fiat Linea T-Jet', 'Fiat Petra 1.2',
#        'Fiat Punto EVO', 'Fiat Siena 1.2', 'Force One LX',
#        'Ford Aspire Ambiente', 'Ford Aspire Titanium', 'Ford Classic 1.4',
#        'Ford EcoSport 1.0', 'Ford EcoSport 1.5', 'Ford Ecosport 1.0',
#        'Ford Ecosport 1.5', 'Ford Ecosport Signature',
#        'Ford Endeavour 2.2', 'Ford Endeavour 2.5L', 'Ford Endeavour 3.0L',
#        'Ford Endeavour 3.2', 'Ford Endeavour 4x2',
#        'Ford Endeavour Hurricane', 'Ford Endeavour Titanium',
#        'Ford Endeavour XLT', 'Ford Fiesta 1.4', 'Ford Fiesta 1.5',
#        'Ford Fiesta 1.6', 'Ford Fiesta Classic', 'Ford Fiesta Diesel',
#        'Ford Fiesta EXi', 'Ford Fiesta Titanium', 'Ford Figo 1.2P',
#        'Ford Figo 1.5D', 'Ford Figo 2015-2019', 'Ford Figo Aspire',
#        'Ford Figo Diesel', 'Ford Figo Petrol', 'Ford Figo Titanium',
#        'Ford Freestyle Titanium', 'Ford Fusion Plus', 'Ford Ikon 1.3',
#        'Ford Ikon 1.4', 'Ford Ikon 1.6', 'Ford Mustang V8',
#        'Honda Accord 2.4', 'Honda Accord 2001-2003', 'Honda Accord V6',
#        'Honda Accord VTi-L', 'Honda Amaze E', 'Honda Amaze EX',
#        'Honda Amaze S', 'Honda Amaze SX', 'Honda Amaze V',
#        'Honda Amaze VX', 'Honda BR-V i-DTEC', 'Honda BR-V i-VTEC',
#        'Honda BRV i-VTEC', 'Honda Brio 1.2', 'Honda Brio E',
#        'Honda Brio EX', 'Honda Brio S', 'Honda Brio V', 'Honda Brio VX',
#        'Honda CR-V 2.0', 'Honda CR-V 2.0L', 'Honda CR-V 2.4',
#        'Honda CR-V 2.4L', 'Honda CR-V Petrol', 'Honda CR-V RVi',
#        'Honda CR-V Sport', 'Honda City 1.3', 'Honda City 1.5',
#        'Honda City Corporate', 'Honda City V', 'Honda City ZX',
#        'Honda City i', 'Honda City i-DTEC', 'Honda City i-VTEC',
#        'Honda Civic 2006-2010', 'Honda Civic 2010-2013', 'Honda Jazz 1.2',
#        'Honda Jazz 1.5', 'Honda Jazz Active', 'Honda Jazz Exclusive',
#        'Honda Jazz Mode', 'Honda Jazz S', 'Honda Jazz Select',
#        'Honda Jazz V', 'Honda Jazz VX', 'Honda Mobilio E',
#        'Honda Mobilio RS', 'Honda Mobilio S', 'Honda Mobilio V',
#        'Honda WR-V Edge', 'Honda WRV i-VTEC', 'Hyundai Accent CRDi',
#        'Hyundai Accent Executive', 'Hyundai Accent GLE',
#        'Hyundai Accent GLS', 'Hyundai Creta 1.4', 'Hyundai Creta 1.6',
#        'Hyundai EON 1.0', 'Hyundai EON D', 'Hyundai EON Era',
#        'Hyundai EON LPG', 'Hyundai EON Magna', 'Hyundai EON Sportz',
#        'Hyundai Elantra 1.6', 'Hyundai Elantra 2.0',
#        'Hyundai Elantra CRDi', 'Hyundai Elantra SX', 'Hyundai Elite i20',
#        'Hyundai Getz 1.3', 'Hyundai Getz 1.5', 'Hyundai Getz GLE',
#        'Hyundai Getz GLS', 'Hyundai Getz GVS', 'Hyundai Grand i10',
#        'Hyundai Santa Fe', 'Hyundai Santro AT', 'Hyundai Santro D',
#        'Hyundai Santro DX', 'Hyundai Santro GLS', 'Hyundai Santro GS',
#        'Hyundai Santro LP', 'Hyundai Santro LS', 'Hyundai Santro Xing',
#        'Hyundai Sonata 2.4', 'Hyundai Sonata Embera',
#        'Hyundai Sonata GOLD', 'Hyundai Sonata Transform',
#        'Hyundai Tucson 2.0', 'Hyundai Tucson CRDi', 'Hyundai Verna 1.4',
#        'Hyundai Verna 1.6', 'Hyundai Verna CRDi', 'Hyundai Verna SX',
#        'Hyundai Verna Transform', 'Hyundai Verna VTVT',
#        'Hyundai Verna XXi', 'Hyundai Verna Xi', 'Hyundai Xcent 1.1',
#        'Hyundai Xcent 1.2', 'Hyundai i10 Asta', 'Hyundai i10 Era',
#        'Hyundai i10 Magna', 'Hyundai i10 Magna(O)', 'Hyundai i10 Sportz',
#        'Hyundai i20 1.2', 'Hyundai i20 1.4', 'Hyundai i20 2015-2017',
#        'Hyundai i20 Active', 'Hyundai i20 Asta', 'Hyundai i20 Diesel',
#        'Hyundai i20 Era', 'Hyundai i20 Magna', 'Hyundai i20 Sportz',
#        'ISUZU D-MAX V-Cross', 'Isuzu MUX 4WD', 'Jaguar F Type',
#        'Jaguar XE 2.0L', 'Jaguar XE Portfolio', 'Jaguar XF 2.0',
#        'Jaguar XF 2.2', 'Jaguar XF 3.0', 'Jaguar XF Aero',
#        'Jaguar XF Diesel', 'Jaguar XJ 2.0L', 'Jaguar XJ 3.0L',
#        'Jaguar XJ 5.0', 'Jeep Compass 1.4', 'Jeep Compass 2.0',
#        'Lamborghini Gallardo Coupe', 'Land Rover Discovery',
#        'Land Rover Freelander', 'Land Rover Range', 'Mahindra Bolero DI',
#        'Mahindra Bolero SLE', 'Mahindra Bolero SLX',
#        'Mahindra Bolero VLX', 'Mahindra Bolero ZLX',
#        'Mahindra Bolero mHAWK', 'Mahindra Jeep MM', 'Mahindra KUV 100',
#        'Mahindra Logan Diesel', 'Mahindra Logan Petrol',
#        'Mahindra NuvoSport N6', 'Mahindra NuvoSport N8',
#        'Mahindra Quanto C2', 'Mahindra Quanto C4', 'Mahindra Quanto C6',
#        'Mahindra Quanto C8', 'Mahindra Renault Logan',
#        'Mahindra Scorpio 1.99', 'Mahindra Scorpio 2.6',
#        'Mahindra Scorpio 2009-2014', 'Mahindra Scorpio DX',
#        'Mahindra Scorpio LX', 'Mahindra Scorpio S10',
#        'Mahindra Scorpio S2', 'Mahindra Scorpio S4',
#        'Mahindra Scorpio S6', 'Mahindra Scorpio S8',
#        'Mahindra Scorpio SLE', 'Mahindra Scorpio SLX',
#        'Mahindra Scorpio VLX', 'Mahindra Ssangyong Rexton',
#        'Mahindra TUV 300', 'Mahindra Thar CRDe', 'Mahindra Thar DI',
#        'Mahindra Verito 1.5', 'Mahindra XUV300 W8', 'Mahindra XUV500 AT',
#        'Mahindra XUV500 W10', 'Mahindra XUV500 W4', 'Mahindra XUV500 W6',
#        'Mahindra XUV500 W7', 'Mahindra XUV500 W8', 'Mahindra XUV500 W9',
#        'Mahindra Xylo D2', 'Mahindra Xylo D4', 'Mahindra Xylo E2',
#        'Mahindra Xylo E4', 'Mahindra Xylo E8', 'Mahindra Xylo H4',
#        'Maruti 1000 AC', 'Maruti 800 AC', 'Maruti 800 DX',
#        'Maruti 800 Std', 'Maruti A-Star AT', 'Maruti A-Star Lxi',
#        'Maruti A-Star Vxi', 'Maruti Alto 800', 'Maruti Alto Green',
#        'Maruti Alto K10', 'Maruti Alto LX', 'Maruti Alto LXI',
#        'Maruti Alto LXi', 'Maruti Alto Std', 'Maruti Alto VXi',
#        'Maruti Alto Vxi', 'Maruti Baleno Alpha', 'Maruti Baleno Delta',
#        'Maruti Baleno LXI', 'Maruti Baleno RS', 'Maruti Baleno Sigma',
#        'Maruti Baleno Vxi', 'Maruti Baleno Zeta', 'Maruti Celerio CNG',
#        'Maruti Celerio LDi', 'Maruti Celerio LXI', 'Maruti Celerio VXI',
#        'Maruti Celerio ZDi', 'Maruti Celerio ZXI', 'Maruti Ciaz 1.3',
#        'Maruti Ciaz 1.4', 'Maruti Ciaz AT', 'Maruti Ciaz Alpha',
#        'Maruti Ciaz RS', 'Maruti Ciaz VDI', 'Maruti Ciaz VDi',
#        'Maruti Ciaz VXi', 'Maruti Ciaz ZDi', 'Maruti Ciaz ZXi',
#        'Maruti Ciaz Zeta', 'Maruti Dzire AMT', 'Maruti Dzire LDI',
#        'Maruti Dzire New', 'Maruti Dzire VDI', 'Maruti Dzire VXI',
#        'Maruti Dzire ZDI', 'Maruti Eeco 5', 'Maruti Eeco 7',
#        'Maruti Eeco CNG', 'Maruti Eeco Smiles', 'Maruti Ertiga LXI',
#        'Maruti Ertiga Paseo', 'Maruti Ertiga SHVS', 'Maruti Ertiga VDI',
#        'Maruti Ertiga VXI', 'Maruti Ertiga ZDI', 'Maruti Ertiga ZXI',
#        'Maruti Esteem LX', 'Maruti Esteem Vxi', 'Maruti Grand Vitara',
#        'Maruti Ignis 1.2', 'Maruti Ignis 1.3', 'Maruti Omni 5',
#        'Maruti Omni 8', 'Maruti Omni E', 'Maruti Omni MPI',
#        'Maruti Ritz AT', 'Maruti Ritz LDi', 'Maruti Ritz LXI',
#        'Maruti Ritz LXi', 'Maruti Ritz VDI', 'Maruti Ritz VDi',
#        'Maruti Ritz VXI', 'Maruti Ritz VXi', 'Maruti Ritz ZDi',
#        'Maruti Ritz ZXI', 'Maruti Ritz ZXi', 'Maruti S Cross',
#        'Maruti S-Cross Alpha', 'Maruti S-Cross Delta',
#        'Maruti S-Cross Zeta', 'Maruti SX4 Green', 'Maruti SX4 S',
#        'Maruti SX4 VDI', 'Maruti SX4 Vxi', 'Maruti SX4 ZDI',
#        'Maruti SX4 ZXI', 'Maruti SX4 Zxi', 'Maruti Swift AMT',
#        'Maruti Swift DDiS', 'Maruti Swift Dzire', 'Maruti Swift LDI',
#        'Maruti Swift LXI', 'Maruti Swift LXi', 'Maruti Swift Ldi',
#        'Maruti Swift Lxi', 'Maruti Swift RS', 'Maruti Swift VDI',
#        'Maruti Swift VDi', 'Maruti Swift VVT', 'Maruti Swift VXI',
#        'Maruti Swift VXi', 'Maruti Swift Vdi', 'Maruti Swift ZDI',
#        'Maruti Swift ZDi', 'Maruti Swift ZXI', 'Maruti Versa DX2',
#        'Maruti Vitara Brezza', 'Maruti Wagon R', 'Maruti Zen Estilo',
#        'Maruti Zen LX', 'Maruti Zen LXI', 'Maruti Zen LXi',
#        'Maruti Zen VX', 'Maruti Zen VXI', 'Maruti Zen VXi',
#        'Mercedes-Benz A Class', 'Mercedes-Benz B Class',
#        'Mercedes-Benz C-Class Progressive', 'Mercedes-Benz CLA 200',
#        'Mercedes-Benz CLS-Class 2006-2010', 'Mercedes-Benz E-Class 200',
#        'Mercedes-Benz E-Class 2009-2013',
#        'Mercedes-Benz E-Class 2015-2017', 'Mercedes-Benz E-Class 220',
#        'Mercedes-Benz E-Class 230', 'Mercedes-Benz E-Class 250',
#        'Mercedes-Benz E-Class 280', 'Mercedes-Benz E-Class E',
#        'Mercedes-Benz E-Class E250', 'Mercedes-Benz E-Class E270',
#        'Mercedes-Benz E-Class E350', 'Mercedes-Benz E-Class E400',
#        'Mercedes-Benz E-Class Facelift', 'Mercedes-Benz GL-Class 2007',
#        'Mercedes-Benz GL-Class 350', 'Mercedes-Benz GLA Class',
#        'Mercedes-Benz GLC 220', 'Mercedes-Benz GLC 220d',
#        'Mercedes-Benz GLC 43', 'Mercedes-Benz GLE 250d',
#        'Mercedes-Benz GLE 350d', 'Mercedes-Benz GLS 350d',
#        'Mercedes-Benz M-Class ML', 'Mercedes-Benz New C-Class',
#        'Mercedes-Benz R-Class R350', 'Mercedes-Benz S Class',
#        'Mercedes-Benz S-Class 280', 'Mercedes-Benz S-Class 320',
#        'Mercedes-Benz S-Class S', 'Mercedes-Benz SL-Class SL',
#        'Mercedes-Benz SLC 43', 'Mercedes-Benz SLK-Class 55',
#        'Mercedes-Benz SLK-Class SLK', 'Mini Clubman Cooper',
#        'Mini Cooper 3', 'Mini Cooper 5', 'Mini Cooper Convertible',
#        'Mini Cooper Countryman', 'Mini Cooper S',
#        'Mini Countryman Cooper', 'Mitsubishi Cedia Sports',
#        'Mitsubishi Lancer 1.5', 'Mitsubishi Lancer GLXD',
#        'Mitsubishi Montero 3.2', 'Mitsubishi Outlander 2.4',
#        'Mitsubishi Pajero 2.8', 'Mitsubishi Pajero 4X4',
#        'Mitsubishi Pajero Sport', 'Nissan Evalia 2013',
#        'Nissan Micra Active', 'Nissan Micra Diesel', 'Nissan Micra XE',
#        'Nissan Micra XL', 'Nissan Micra XV', 'Nissan Sunny 2011-2014',
#        'Nissan Sunny Diesel', 'Nissan Sunny XE', 'Nissan Sunny XL',
#        'Nissan Sunny XV', 'Nissan Teana 230jM', 'Nissan Teana XV',
#        'Nissan Terrano XL', 'Nissan Terrano XV', 'Nissan X-Trail SLX',
#        'Porsche Boxster S', 'Porsche Cayenne 2009-2014',
#        'Porsche Cayenne Base', 'Porsche Cayenne Diesel',
#        'Porsche Cayenne S', 'Porsche Cayenne Turbo',
#        'Porsche Cayman 2009-2012', 'Porsche Panamera 2010',
#        'Porsche Panamera Diesel', 'Renault Captur 1.5',
#        'Renault Duster 110PS', 'Renault Duster 85PS',
#        'Renault Duster Adventure', 'Renault Duster Petrol',
#        'Renault Duster RXZ', 'Renault Fluence 1.5', 'Renault Fluence 2.0',
#        'Renault Fluence Diesel', 'Renault KWID 1.0', 'Renault KWID AMT',
#        'Renault KWID Climber', 'Renault KWID RXL', 'Renault KWID RXT',
#        'Renault Koleos 2.0', 'Renault Lodgy 110PS',
#        'Renault Pulse Petrol', 'Renault Pulse RxL',
#        'Renault Scala Diesel', 'Renault Scala RxL', 'Skoda Fabia 1.2',
#        'Skoda Fabia 1.2L', 'Skoda Fabia 1.4', 'Skoda Fabia 1.6',
#        'Skoda Laura 1.8', 'Skoda Laura 1.9', 'Skoda Laura Ambiente',
#        'Skoda Laura Ambition', 'Skoda Laura Classic',
#        'Skoda Laura Elegance', 'Skoda Laura L', 'Skoda Laura RS',
#        'Skoda Octavia 1.9', 'Skoda Octavia 2.0', 'Skoda Octavia Ambiente',
#        'Skoda Octavia Ambition', 'Skoda Octavia Classic',
#        'Skoda Octavia Elegance', 'Skoda Octavia L', 'Skoda Octavia RS',
#        'Skoda Octavia Rider', 'Skoda Octavia Style', 'Skoda Rapid 1.5',
#        'Skoda Rapid 1.6', 'Skoda Rapid 2013-2016', 'Skoda Rapid Leisure',
#        'Skoda Rapid Ultima', 'Skoda Superb 1.8', 'Skoda Superb 2.5',
#        'Skoda Superb 2.8', 'Skoda Superb 2009-2014', 'Skoda Superb 3.6',
#        'Skoda Superb Ambition', 'Skoda Superb Elegance',
#        'Skoda Superb L&K', 'Skoda Superb Style', 'Skoda Yeti Ambition',
#        'Skoda Yeti Elegance', 'Smart Fortwo CDI', 'Tata Bolt Quadrajet',
#        'Tata Bolt Revotron', 'Tata Hexa XT', 'Tata Hexa XTA',
#        'Tata Indica DLS', 'Tata Indica GLS', 'Tata Indica LEI',
#        'Tata Indica V2', 'Tata Indica Vista', 'Tata Indigo CS',
#        'Tata Indigo GLE', 'Tata Indigo LS', 'Tata Indigo LX',
#        'Tata Indigo XL', 'Tata Indigo eCS', 'Tata Manza Aqua',
#        'Tata Manza Aura', 'Tata Manza Club', 'Tata Manza ELAN',
#        'Tata Nano CX', 'Tata Nano Cx', 'Tata Nano LX', 'Tata Nano Lx',
#        'Tata Nano STD', 'Tata Nano Twist', 'Tata Nano XT',
#        'Tata Nano XTA', 'Tata New Safari', 'Tata Nexon 1.2',
#        'Tata Nexon 1.5', 'Tata Safari DICOR', 'Tata Safari Storme',
#        'Tata Sumo DX', 'Tata Sumo Delux', 'Tata Sumo EX',
#        'Tata Tiago 1.2', 'Tata Tiago AMT', 'Tata Tiago Wizz',
#        'Tata Tigor 1.05', 'Tata Tigor 1.2', 'Tata Tigor XE',
#        'Tata Venture EX', 'Tata Xenon XT', 'Tata Zest Quadrajet',
#        'Tata Zest Revotron', 'Toyota Camry 2.5', 'Toyota Camry A/T',
#        'Toyota Camry Hybrid', 'Toyota Camry W2', 'Toyota Camry W4',
#        'Toyota Corolla 1.8', 'Toyota Corolla Altis', 'Toyota Corolla DX',
#        'Toyota Corolla Executive', 'Toyota Corolla H2',
#        'Toyota Corolla H4', 'Toyota Corolla H5', 'Toyota Etios 1.4',
#        'Toyota Etios Cross', 'Toyota Etios G', 'Toyota Etios GD',
#        'Toyota Etios Liva', 'Toyota Etios Petrol', 'Toyota Etios V',
#        'Toyota Etios VD', 'Toyota Etios VX', 'Toyota Etios VXD',
#        'Toyota Fortuner 2.8', 'Toyota Fortuner 3.0',
#        'Toyota Fortuner 4x2', 'Toyota Fortuner 4x4',
#        'Toyota Fortuner TRD', 'Toyota Innova 2.0', 'Toyota Innova 2.5',
#        'Toyota Innova Crysta', 'Toyota Platinum Etios',
#        'Toyota Qualis FS', 'Toyota Qualis RS', 'Volkswagen Ameo 1.2',
#        'Volkswagen Ameo 1.5', 'Volkswagen Beetle 2.0',
#        'Volkswagen CrossPolo 1.5', 'Volkswagen Jetta 2007-2011',
#        'Volkswagen Jetta 2012-2014', 'Volkswagen Jetta 2013-2015',
#        'Volkswagen Passat 1.8', 'Volkswagen Passat 2.0',
#        'Volkswagen Passat Diesel', 'Volkswagen Passat Highline',
#        'Volkswagen Polo 1.0', 'Volkswagen Polo 1.2',
#        'Volkswagen Polo 1.5', 'Volkswagen Polo Diesel',
#        'Volkswagen Polo GT', 'Volkswagen Polo GTI', 'Volkswagen Polo IPL',
#        'Volkswagen Polo Petrol', 'Volkswagen Tiguan 2.0',
#        'Volkswagen Vento 1.2', 'Volkswagen Vento 1.5',
#        'Volkswagen Vento 1.6', 'Volkswagen Vento 2013-2015',
#        'Volkswagen Vento Diesel', 'Volkswagen Vento IPL',
#        'Volkswagen Vento Konekt', 'Volkswagen Vento Magnific',
#        'Volkswagen Vento Petrol', 'Volkswagen Vento Sport',
#        'Volkswagen Vento TSI', 'Volvo S60 D3', 'Volvo S60 D4',
#        'Volvo S60 D5', 'Volvo S80 2006-2013', 'Volvo S80 D5',
#        'Volvo V40 Cross', 'Volvo V40 D3', 'Volvo XC60 D4',
#        'Volvo XC60 D5', 'Volvo XC90 2007-2015'], dtype=object)

# %% [markdown]
# **Naive Bayes**

# %%
NB = GaussianNB()
pipe_NB = make_pipeline(column_trans,reg)
pipe_NB.fit(X_train,Y_train)
y_pred_NB = pipe_NB.predict(X_test)
r2_score(Y_test,y_pred_NB)
# Out:
# 0.8860422459389669

# %%
pipe.predict(pd.DataFrame([['Hyundai i20 Sportz','Ahmedabad',2015,110000,'Diesel','Manual','First', 20.00, 	1400,	5,'Hyundai']],columns=['Name',	'Location',	'Year',	'Kilometers_Driven',	'Fuel_Type',	'Transmission',	'Owner_Type',	'Mileage',	'Engine',	'Seats',	'company']))
# Out:
# array([7.65630644])

# %%
#for slection of car object
pipe.steps[0][1].transformers[0][1].categories[0]
# Out:
# array(['Ambassador Classic Nova', 'Audi A3 35', 'Audi A4 1.8',
#        'Audi A4 2.0', 'Audi A4 3.0', 'Audi A4 30', 'Audi A4 35',
#        'Audi A4 New', 'Audi A6 2.0', 'Audi A6 2.7', 'Audi A6 2.8',
#        'Audi A6 2011-2015', 'Audi A6 3.0', 'Audi A6 35',
#        'Audi A7 2011-2015', 'Audi A8 L', 'Audi Q3 2.0',
#        'Audi Q3 2012-2015', 'Audi Q3 30', 'Audi Q3 35', 'Audi Q5 2.0',
#        'Audi Q5 2008-2012', 'Audi Q5 3.0', 'Audi Q5 30', 'Audi Q7 3.0',
#        'Audi Q7 35', 'Audi Q7 4.2', 'Audi Q7 45', 'Audi RS5 Coupe',
#        'Audi TT 2.0', 'Audi TT 40', 'BMW 1 Series', 'BMW 3 Series',
#        'BMW 5 Series', 'BMW 6 Series', 'BMW 7 Series', 'BMW X1 M',
#        'BMW X1 sDrive', 'BMW X1 sDrive20d', 'BMW X1 xDrive',
#        'BMW X3 xDrive', 'BMW X3 xDrive20d', 'BMW X3 xDrive30d',
#        'BMW X5 2014-2019', 'BMW X5 3.0d', 'BMW X5 X5', 'BMW X5 xDrive',
#        'BMW X6 xDrive', 'BMW X6 xDrive30d', 'BMW Z4 2009-2013',
#        'Bentley Continental Flying', 'Chevrolet Aveo 1.4',
#        'Chevrolet Aveo 1.6', 'Chevrolet Aveo U-VA',
#        'Chevrolet Beat Diesel', 'Chevrolet Beat LS', 'Chevrolet Beat LT',
#        'Chevrolet Beat Option', 'Chevrolet Captiva LT',
#        'Chevrolet Captiva LTZ', 'Chevrolet Cruze LTZ',
#        'Chevrolet Enjoy 1.3', 'Chevrolet Enjoy 1.4',
#        'Chevrolet Enjoy Petrol', 'Chevrolet Enjoy TCDi',
#        'Chevrolet Optra 1.6', 'Chevrolet Optra Magnum',
#        'Chevrolet Sail 1.2', 'Chevrolet Sail Hatchback',
#        'Chevrolet Sail LT', 'Chevrolet Spark 1.0', 'Chevrolet Tavera LS',
#        'Chevrolet Tavera LT', 'Datsun GO NXT', 'Datsun GO Plus',
#        'Datsun GO T', 'Datsun Redi GO', 'Datsun redi-GO S',
#        'Datsun redi-GO T', 'Fiat Avventura MULTIJET', 'Fiat Grande Punto',
#        'Fiat Linea 1.3', 'Fiat Linea Classic', 'Fiat Linea Emotion',
#        'Fiat Linea T', 'Fiat Linea T-Jet', 'Fiat Petra 1.2',
#        'Fiat Punto EVO', 'Fiat Siena 1.2', 'Force One LX',
#        'Ford Aspire Ambiente', 'Ford Aspire Titanium', 'Ford Classic 1.4',
#        'Ford EcoSport 1.0', 'Ford EcoSport 1.5', 'Ford Ecosport 1.0',
#        'Ford Ecosport 1.5', 'Ford Ecosport Signature',
#        'Ford Endeavour 2.2', 'Ford Endeavour 2.5L', 'Ford Endeavour 3.0L',
#        'Ford Endeavour 3.2', 'Ford Endeavour 4x2',
#        'Ford Endeavour Hurricane', 'Ford Endeavour Titanium',
#        'Ford Endeavour XLT', 'Ford Fiesta 1.4', 'Ford Fiesta 1.5',
#        'Ford Fiesta 1.6', 'Ford Fiesta Classic', 'Ford Fiesta Diesel',
#        'Ford Fiesta EXi', 'Ford Fiesta Titanium', 'Ford Figo 1.2P',
#        'Ford Figo 1.5D', 'Ford Figo 2015-2019', 'Ford Figo Aspire',
#        'Ford Figo Diesel', 'Ford Figo Petrol', 'Ford Figo Titanium',
#        'Ford Freestyle Titanium', 'Ford Fusion Plus', 'Ford Ikon 1.3',
#        'Ford Ikon 1.4', 'Ford Ikon 1.6', 'Ford Mustang V8',
#        'Honda Accord 2.4', 'Honda Accord 2001-2003', 'Honda Accord V6',
#        'Honda Accord VTi-L', 'Honda Amaze E', 'Honda Amaze EX',
#        'Honda Amaze S', 'Honda Amaze SX', 'Honda Amaze V',
#        'Honda Amaze VX', 'Honda BR-V i-DTEC', 'Honda BR-V i-VTEC',
#        'Honda BRV i-VTEC', 'Honda Brio 1.2', 'Honda Brio E',
#        'Honda Brio EX', 'Honda Brio S', 'Honda Brio V', 'Honda Brio VX',
#        'Honda CR-V 2.0', 'Honda CR-V 2.0L', 'Honda CR-V 2.4',
#        'Honda CR-V 2.4L', 'Honda CR-V Petrol', 'Honda CR-V RVi',
#        'Honda CR-V Sport', 'Honda City 1.3', 'Honda City 1.5',
#        'Honda City Corporate', 'Honda City V', 'Honda City ZX',
#        'Honda City i', 'Honda City i-DTEC', 'Honda City i-VTEC',
#        'Honda Civic 2006-2010', 'Honda Civic 2010-2013', 'Honda Jazz 1.2',
#        'Honda Jazz 1.5', 'Honda Jazz Active', 'Honda Jazz Exclusive',
#        'Honda Jazz Mode', 'Honda Jazz S', 'Honda Jazz Select',
#        'Honda Jazz V', 'Honda Jazz VX', 'Honda Mobilio E',
#        'Honda Mobilio RS', 'Honda Mobilio S', 'Honda Mobilio V',
#        'Honda WR-V Edge', 'Honda WRV i-VTEC', 'Hyundai Accent CRDi',
#        'Hyundai Accent Executive', 'Hyundai Accent GLE',
#        'Hyundai Accent GLS', 'Hyundai Creta 1.4', 'Hyundai Creta 1.6',
#        'Hyundai EON 1.0', 'Hyundai EON D', 'Hyundai EON Era',
#        'Hyundai EON LPG', 'Hyundai EON Magna', 'Hyundai EON Sportz',
#        'Hyundai Elantra 1.6', 'Hyundai Elantra 2.0',
#        'Hyundai Elantra CRDi', 'Hyundai Elantra SX', 'Hyundai Elite i20',
#        'Hyundai Getz 1.3', 'Hyundai Getz 1.5', 'Hyundai Getz GLE',
#        'Hyundai Getz GLS', 'Hyundai Getz GVS', 'Hyundai Grand i10',
#        'Hyundai Santa Fe', 'Hyundai Santro AT', 'Hyundai Santro D',
#        'Hyundai Santro DX', 'Hyundai Santro GLS', 'Hyundai Santro GS',
#        'Hyundai Santro LP', 'Hyundai Santro LS', 'Hyundai Santro Xing',
#        'Hyundai Sonata 2.4', 'Hyundai Sonata Embera',
#        'Hyundai Sonata GOLD', 'Hyundai Sonata Transform',
#        'Hyundai Tucson 2.0', 'Hyundai Tucson CRDi', 'Hyundai Verna 1.4',
#        'Hyundai Verna 1.6', 'Hyundai Verna CRDi', 'Hyundai Verna SX',
#        'Hyundai Verna Transform', 'Hyundai Verna VTVT',
#        'Hyundai Verna XXi', 'Hyundai Verna Xi', 'Hyundai Xcent 1.1',
#        'Hyundai Xcent 1.2', 'Hyundai i10 Asta', 'Hyundai i10 Era',
#        'Hyundai i10 Magna', 'Hyundai i10 Magna(O)', 'Hyundai i10 Sportz',
#        'Hyundai i20 1.2', 'Hyundai i20 1.4', 'Hyundai i20 2015-2017',
#        'Hyundai i20 Active', 'Hyundai i20 Asta', 'Hyundai i20 Diesel',
#        'Hyundai i20 Era', 'Hyundai i20 Magna', 'Hyundai i20 Sportz',
#        'ISUZU D-MAX V-Cross', 'Isuzu MUX 4WD', 'Jaguar F Type',
#        'Jaguar XE 2.0L', 'Jaguar XE Portfolio', 'Jaguar XF 2.0',
#        'Jaguar XF 2.2', 'Jaguar XF 3.0', 'Jaguar XF Aero',
#        'Jaguar XF Diesel', 'Jaguar XJ 2.0L', 'Jaguar XJ 3.0L',
#        'Jaguar XJ 5.0', 'Jeep Compass 1.4', 'Jeep Compass 2.0',
#        'Lamborghini Gallardo Coupe', 'Land Rover Discovery',
#        'Land Rover Freelander', 'Land Rover Range', 'Mahindra Bolero DI',
#        'Mahindra Bolero SLE', 'Mahindra Bolero SLX',
#        'Mahindra Bolero VLX', 'Mahindra Bolero ZLX',
#        'Mahindra Bolero mHAWK', 'Mahindra Jeep MM', 'Mahindra KUV 100',
#        'Mahindra Logan Diesel', 'Mahindra Logan Petrol',
#        'Mahindra NuvoSport N6', 'Mahindra NuvoSport N8',
#        'Mahindra Quanto C2', 'Mahindra Quanto C4', 'Mahindra Quanto C6',
#        'Mahindra Quanto C8', 'Mahindra Renault Logan',
#        'Mahindra Scorpio 1.99', 'Mahindra Scorpio 2.6',
#        'Mahindra Scorpio 2009-2014', 'Mahindra Scorpio DX',
#        'Mahindra Scorpio LX', 'Mahindra Scorpio S10',
#        'Mahindra Scorpio S2', 'Mahindra Scorpio S4',
#        'Mahindra Scorpio S6', 'Mahindra Scorpio S8',
#        'Mahindra Scorpio SLE', 'Mahindra Scorpio SLX',
#        'Mahindra Scorpio VLX', 'Mahindra Ssangyong Rexton',
#        'Mahindra TUV 300', 'Mahindra Thar CRDe', 'Mahindra Thar DI',
#        'Mahindra Verito 1.5', 'Mahindra XUV300 W8', 'Mahindra XUV500 AT',
#        'Mahindra XUV500 W10', 'Mahindra XUV500 W4', 'Mahindra XUV500 W6',
#        'Mahindra XUV500 W7', 'Mahindra XUV500 W8', 'Mahindra XUV500 W9',
#        'Mahindra Xylo D2', 'Mahindra Xylo D4', 'Mahindra Xylo E2',
#        'Mahindra Xylo E4', 'Mahindra Xylo E8', 'Mahindra Xylo H4',
#        'Maruti 1000 AC', 'Maruti 800 AC', 'Maruti 800 DX',
#        'Maruti 800 Std', 'Maruti A-Star AT', 'Maruti A-Star Lxi',
#        'Maruti A-Star Vxi', 'Maruti Alto 800', 'Maruti Alto Green',
#        'Maruti Alto K10', 'Maruti Alto LX', 'Maruti Alto LXI',
#        'Maruti Alto LXi', 'Maruti Alto Std', 'Maruti Alto VXi',
#        'Maruti Alto Vxi', 'Maruti Baleno Alpha', 'Maruti Baleno Delta',
#        'Maruti Baleno LXI', 'Maruti Baleno RS', 'Maruti Baleno Sigma',
#        'Maruti Baleno Vxi', 'Maruti Baleno Zeta', 'Maruti Celerio CNG',
#        'Maruti Celerio LDi', 'Maruti Celerio LXI', 'Maruti Celerio VXI',
#        'Maruti Celerio ZDi', 'Maruti Celerio ZXI', 'Maruti Ciaz 1.3',
#        'Maruti Ciaz 1.4', 'Maruti Ciaz AT', 'Maruti Ciaz Alpha',
#        'Maruti Ciaz RS', 'Maruti Ciaz VDI', 'Maruti Ciaz VDi',
#        'Maruti Ciaz VXi', 'Maruti Ciaz ZDi', 'Maruti Ciaz ZXi',
#        'Maruti Ciaz Zeta', 'Maruti Dzire AMT', 'Maruti Dzire LDI',
#        'Maruti Dzire New', 'Maruti Dzire VDI', 'Maruti Dzire VXI',
#        'Maruti Dzire ZDI', 'Maruti Eeco 5', 'Maruti Eeco 7',
#        'Maruti Eeco CNG', 'Maruti Eeco Smiles', 'Maruti Ertiga LXI',
#        'Maruti Ertiga Paseo', 'Maruti Ertiga SHVS', 'Maruti Ertiga VDI',
#        'Maruti Ertiga VXI', 'Maruti Ertiga ZDI', 'Maruti Ertiga ZXI',
#        'Maruti Esteem LX', 'Maruti Esteem Vxi', 'Maruti Grand Vitara',
#        'Maruti Ignis 1.2', 'Maruti Ignis 1.3', 'Maruti Omni 5',
#        'Maruti Omni 8', 'Maruti Omni E', 'Maruti Omni MPI',
#        'Maruti Ritz AT', 'Maruti Ritz LDi', 'Maruti Ritz LXI',
#        'Maruti Ritz LXi', 'Maruti Ritz VDI', 'Maruti Ritz VDi',
#        'Maruti Ritz VXI', 'Maruti Ritz VXi', 'Maruti Ritz ZDi',
#        'Maruti Ritz ZXI', 'Maruti Ritz ZXi', 'Maruti S Cross',
#        'Maruti S-Cross Alpha', 'Maruti S-Cross Delta',
#        'Maruti S-Cross Zeta', 'Maruti SX4 Green', 'Maruti SX4 S',
#        'Maruti SX4 VDI', 'Maruti SX4 Vxi', 'Maruti SX4 ZDI',
#        'Maruti SX4 ZXI', 'Maruti SX4 Zxi', 'Maruti Swift AMT',
#        'Maruti Swift DDiS', 'Maruti Swift Dzire', 'Maruti Swift LDI',
#        'Maruti Swift LXI', 'Maruti Swift LXi', 'Maruti Swift Ldi',
#        'Maruti Swift Lxi', 'Maruti Swift RS', 'Maruti Swift VDI',
#        'Maruti Swift VDi', 'Maruti Swift VVT', 'Maruti Swift VXI',
#        'Maruti Swift VXi', 'Maruti Swift Vdi', 'Maruti Swift ZDI',
#        'Maruti Swift ZDi', 'Maruti Swift ZXI', 'Maruti Versa DX2',
#        'Maruti Vitara Brezza', 'Maruti Wagon R', 'Maruti Zen Estilo',
#        'Maruti Zen LX', 'Maruti Zen LXI', 'Maruti Zen LXi',
#        'Maruti Zen VX', 'Maruti Zen VXI', 'Maruti Zen VXi',
#        'Mercedes-Benz A Class', 'Mercedes-Benz B Class',
#        'Mercedes-Benz C-Class Progressive', 'Mercedes-Benz CLA 200',
#        'Mercedes-Benz CLS-Class 2006-2010', 'Mercedes-Benz E-Class 200',
#        'Mercedes-Benz E-Class 2009-2013',
#        'Mercedes-Benz E-Class 2015-2017', 'Mercedes-Benz E-Class 220',
#        'Mercedes-Benz E-Class 230', 'Mercedes-Benz E-Class 250',
#        'Mercedes-Benz E-Class 280', 'Mercedes-Benz E-Class E',
#        'Mercedes-Benz E-Class E250', 'Mercedes-Benz E-Class E270',
#        'Mercedes-Benz E-Class E350', 'Mercedes-Benz E-Class E400',
#        'Mercedes-Benz E-Class Facelift', 'Mercedes-Benz GL-Class 2007',
#        'Mercedes-Benz GL-Class 350', 'Mercedes-Benz GLA Class',
#        'Mercedes-Benz GLC 220', 'Mercedes-Benz GLC 220d',
#        'Mercedes-Benz GLC 43', 'Mercedes-Benz GLE 250d',
#        'Mercedes-Benz GLE 350d', 'Mercedes-Benz GLS 350d',
#        'Mercedes-Benz M-Class ML', 'Mercedes-Benz New C-Class',
#        'Mercedes-Benz R-Class R350', 'Mercedes-Benz S Class',
#        'Mercedes-Benz S-Class 280', 'Mercedes-Benz S-Class 320',
#        'Mercedes-Benz S-Class S', 'Mercedes-Benz SL-Class SL',
#        'Mercedes-Benz SLC 43', 'Mercedes-Benz SLK-Class 55',
#        'Mercedes-Benz SLK-Class SLK', 'Mini Clubman Cooper',
#        'Mini Cooper 3', 'Mini Cooper 5', 'Mini Cooper Convertible',
#        'Mini Cooper Countryman', 'Mini Cooper S',
#        'Mini Countryman Cooper', 'Mitsubishi Cedia Sports',
#        'Mitsubishi Lancer 1.5', 'Mitsubishi Lancer GLXD',
#        'Mitsubishi Montero 3.2', 'Mitsubishi Outlander 2.4',
#        'Mitsubishi Pajero 2.8', 'Mitsubishi Pajero 4X4',
#        'Mitsubishi Pajero Sport', 'Nissan Evalia 2013',
#        'Nissan Micra Active', 'Nissan Micra Diesel', 'Nissan Micra XE',
#        'Nissan Micra XL', 'Nissan Micra XV', 'Nissan Sunny 2011-2014',
#        'Nissan Sunny Diesel', 'Nissan Sunny XE', 'Nissan Sunny XL',
#        'Nissan Sunny XV', 'Nissan Teana 230jM', 'Nissan Teana XV',
#        'Nissan Terrano XL', 'Nissan Terrano XV', 'Nissan X-Trail SLX',
#        'Porsche Boxster S', 'Porsche Cayenne 2009-2014',
#        'Porsche Cayenne Base', 'Porsche Cayenne Diesel',
#        'Porsche Cayenne S', 'Porsche Cayenne Turbo',
#        'Porsche Cayman 2009-2012', 'Porsche Panamera 2010',
#        'Porsche Panamera Diesel', 'Renault Captur 1.5',
#        'Renault Duster 110PS', 'Renault Duster 85PS',
#        'Renault Duster Adventure', 'Renault Duster Petrol',
#        'Renault Duster RXZ', 'Renault Fluence 1.5', 'Renault Fluence 2.0',
#        'Renault Fluence Diesel', 'Renault KWID 1.0', 'Renault KWID AMT',
#        'Renault KWID Climber', 'Renault KWID RXL', 'Renault KWID RXT',
#        'Renault Koleos 2.0', 'Renault Lodgy 110PS',
#        'Renault Pulse Petrol', 'Renault Pulse RxL',
#        'Renault Scala Diesel', 'Renault Scala RxL', 'Skoda Fabia 1.2',
#        'Skoda Fabia 1.2L', 'Skoda Fabia 1.4', 'Skoda Fabia 1.6',
#        'Skoda Laura 1.8', 'Skoda Laura 1.9', 'Skoda Laura Ambiente',
#        'Skoda Laura Ambition', 'Skoda Laura Classic',
#        'Skoda Laura Elegance', 'Skoda Laura L', 'Skoda Laura RS',
#        'Skoda Octavia 1.9', 'Skoda Octavia 2.0', 'Skoda Octavia Ambiente',
#        'Skoda Octavia Ambition', 'Skoda Octavia Classic',
#        'Skoda Octavia Elegance', 'Skoda Octavia L', 'Skoda Octavia RS',
#        'Skoda Octavia Rider', 'Skoda Octavia Style', 'Skoda Rapid 1.5',
#        'Skoda Rapid 1.6', 'Skoda Rapid 2013-2016', 'Skoda Rapid Leisure',
#        'Skoda Rapid Ultima', 'Skoda Superb 1.8', 'Skoda Superb 2.5',
#        'Skoda Superb 2.8', 'Skoda Superb 2009-2014', 'Skoda Superb 3.6',
#        'Skoda Superb Ambition', 'Skoda Superb Elegance',
#        'Skoda Superb L&K', 'Skoda Superb Style', 'Skoda Yeti Ambition',
#        'Skoda Yeti Elegance', 'Smart Fortwo CDI', 'Tata Bolt Quadrajet',
#        'Tata Bolt Revotron', 'Tata Hexa XT', 'Tata Hexa XTA',
#        'Tata Indica DLS', 'Tata Indica GLS', 'Tata Indica LEI',
#        'Tata Indica V2', 'Tata Indica Vista', 'Tata Indigo CS',
#        'Tata Indigo GLE', 'Tata Indigo LS', 'Tata Indigo LX',
#        'Tata Indigo XL', 'Tata Indigo eCS', 'Tata Manza Aqua',
#        'Tata Manza Aura', 'Tata Manza Club', 'Tata Manza ELAN',
#        'Tata Nano CX', 'Tata Nano Cx', 'Tata Nano LX', 'Tata Nano Lx',
#        'Tata Nano STD', 'Tata Nano Twist', 'Tata Nano XT',
#        'Tata Nano XTA', 'Tata New Safari', 'Tata Nexon 1.2',
#        'Tata Nexon 1.5', 'Tata Safari DICOR', 'Tata Safari Storme',
#        'Tata Sumo DX', 'Tata Sumo Delux', 'Tata Sumo EX',
#        'Tata Tiago 1.2', 'Tata Tiago AMT', 'Tata Tiago Wizz',
#        'Tata Tigor 1.05', 'Tata Tigor 1.2', 'Tata Tigor XE',
#        'Tata Venture EX', 'Tata Xenon XT', 'Tata Zest Quadrajet',
#        'Tata Zest Revotron', 'Toyota Camry 2.5', 'Toyota Camry A/T',
#        'Toyota Camry Hybrid', 'Toyota Camry W2', 'Toyota Camry W4',
#        'Toyota Corolla 1.8', 'Toyota Corolla Altis', 'Toyota Corolla DX',
#        'Toyota Corolla Executive', 'Toyota Corolla H2',
#        'Toyota Corolla H4', 'Toyota Corolla H5', 'Toyota Etios 1.4',
#        'Toyota Etios Cross', 'Toyota Etios G', 'Toyota Etios GD',
#        'Toyota Etios Liva', 'Toyota Etios Petrol', 'Toyota Etios V',
#        'Toyota Etios VD', 'Toyota Etios VX', 'Toyota Etios VXD',
#        'Toyota Fortuner 2.8', 'Toyota Fortuner 3.0',
#        'Toyota Fortuner 4x2', 'Toyota Fortuner 4x4',
#        'Toyota Fortuner TRD', 'Toyota Innova 2.0', 'Toyota Innova 2.5',
#        'Toyota Innova Crysta', 'Toyota Platinum Etios',
#        'Toyota Qualis FS', 'Toyota Qualis RS', 'Volkswagen Ameo 1.2',
#        'Volkswagen Ameo 1.5', 'Volkswagen Beetle 2.0',
#        'Volkswagen CrossPolo 1.5', 'Volkswagen Jetta 2007-2011',
#        'Volkswagen Jetta 2012-2014', 'Volkswagen Jetta 2013-2015',
#        'Volkswagen Passat 1.8', 'Volkswagen Passat 2.0',
#        'Volkswagen Passat Diesel', 'Volkswagen Passat Highline',
#        'Volkswagen Polo 1.0', 'Volkswagen Polo 1.2',
#        'Volkswagen Polo 1.5', 'Volkswagen Polo Diesel',
#        'Volkswagen Polo GT', 'Volkswagen Polo GTI', 'Volkswagen Polo IPL',
#        'Volkswagen Polo Petrol', 'Volkswagen Tiguan 2.0',
#        'Volkswagen Vento 1.2', 'Volkswagen Vento 1.5',
#        'Volkswagen Vento 1.6', 'Volkswagen Vento 2013-2015',
#        'Volkswagen Vento Diesel', 'Volkswagen Vento IPL',
#        'Volkswagen Vento Konekt', 'Volkswagen Vento Magnific',
#        'Volkswagen Vento Petrol', 'Volkswagen Vento Sport',
#        'Volkswagen Vento TSI', 'Volvo S60 D3', 'Volvo S60 D4',
#        'Volvo S60 D5', 'Volvo S80 2006-2013', 'Volvo S80 D5',
#        'Volvo V40 Cross', 'Volvo V40 D3', 'Volvo XC60 D4',
#        'Volvo XC60 D5', 'Volvo XC90 2007-2015'], dtype=object)

# %% [markdown]
# ## analysis
# - all analysis graph

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
import seaborn as sns

# %% [markdown]
# **Price to Company graph with Fuel type and year**

# %%
ax=sns.relplot(x='company',y='Price',data=car,hue='Fuel_Type',size='Year',height=5,aspect=2)
ax.set_xticklabels(rotation=40,ha='right')

# %% [markdown]
# **Price to Company only**

# %%
plt.subplots(figsize=(10,5))
ax=sns.boxplot(x='company',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()

# %% [markdown]
# **Year to price**

# %%
plt.subplots(figsize=(10,5))
ax=sns.swarmplot(x='Year',y='Price',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 25.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 73.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 72.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 85.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 82.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 87.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 90.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 87.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 89.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 90.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 92.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 92.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 92.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 91.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 90.1% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 88.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 81.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 52.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <ipython-input-31-4c6bf5a1d4e6>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 91.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 91.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 92.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 90.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 89.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 87.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 78.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.subplots(figsize=(10,5))
ax=sns.swarmplot(x='company',y='Engine',data=car)
ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 98.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 97.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 96.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 93.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 84.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 93.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 94.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 88.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 77.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 51.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 88.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 92.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 95.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 93.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 90.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 44.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 53.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 72.5% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 71.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 84.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 87.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 69.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 76.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 73.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <ipython-input-32-1688ec298c6a>:3: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels(ax.get_xticklabels(),rotation=40,ha='right')
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 98.2% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 94.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# /usr/local/lib/python3.10/dist-packages/seaborn/categorical.py:3544: UserWarning: 65.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# **Price to Kilometers**

# %%
sns.relplot(x='Kilometers_Driven',y='Price',data=car,height=5,aspect=2)

# %% [markdown]
# **price to fuel type**

# %%
plt.subplots(figsize=(10,5))
sns.boxplot(x='Fuel_Type',y='Price',data=car)
# Out:
# <Axes: xlabel='Fuel_Type', ylabel='Price'>
